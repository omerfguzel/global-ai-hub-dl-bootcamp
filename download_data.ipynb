# %%
from pathlib import Path
import requests
file_url = "https://drive.google.com/drive/folders/1xey3vAVNDjWxnSfhuUsf_5dGANZWmCog?usp=sharing"
	
r = requests.get(file_url, stream = True)
path = "/content/drive/MyDrive/global-ai-hub-bootcamp/spectograms.zip"

with open(path, "wb") as file:
	for block in r.iter_content(chunk_size = 1024):
		if block:
			file.write(block)
